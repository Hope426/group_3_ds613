# %%
#! pip install -r requirements.txt

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder
import joblib
from sklearn.metrics import confusion_matrix

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
# Load the datasets
df_train = pd.read_csv('loan_train.csv')
df_test = pd.read_csv('loan_test.csv')

# View the first 5 rows to confirm it loaded
print("Train Data Shape:", df_train.shape)
display(df_train.head())
# Out:
# Train Data Shape: (614, 13)
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# ...

# %%
df_train['Gender'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
# Check how many missing values are in each column
print("Missing values before cleaning:")
print(df_train.isnull().sum())
# Out:
# Missing values before cleaning:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
# Fill missing LoanAmount with the median
df_train['LoanAmount'] = df_train['LoanAmount'].fillna(df_train['LoanAmount'].median())

# Fill missing Loan_Amount_Term with the median
df_train['Loan_Amount_Term'] = df_train['Loan_Amount_Term'].fillna(df_train['Loan_Amount_Term'].median())

# Fill Credit_History with the most frequent value (Mode)
df_train['Credit_History'] = df_train['Credit_History'].fillna(df_train['Credit_History'].mode()[0])

# %%
# List of categorical columns
cat_cols = ['Gender', 'Married', 'Dependents', 'Self_Employed']

# Loop through and fill with mode
for col in cat_cols:
    df_train[col] = df_train[col].fillna(df_train[col].mode()[0])

# %%
# Drop Loan_ID because it is not useful for prediction
if 'Loan_ID' in df_train.columns:
    df_train = df_train.drop('Loan_ID', axis=1)

# Initialize Encoder
lebel_encoder_cat = LabelEncoder()

# List of columns to encode
cols_to_encode = ['Gender', 'Married', 'Dependents', 'Education',
                  'Self_Employed', 'Property_Area', 'Loan_Status']

# Apply encoding
for col in cols_to_encode:
    df_train[col] = lebel_encoder_cat.fit_transform(df_train[col])


display(df_train.head())
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        0           0          0              0             5849
# 1       1        1           1          0              0             4583
# 2       1        1           0          0              1             3000
# 3       1        1           0          1              0             2583
# 4       1        0           0          0              0             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0       128.0             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#    Property_Area  Loan_Status
# 0              2            1
# 1              0            0
# ...

# %%
# Visualize the target variable (Loan Status)
plt.figure(figsize=(6, 4))
sns.countplot(x='Loan_Status', data=df_train)
plt.title('Distribution of Loan Status (0=No, 1=Yes)')
plt.xlabel('Loan Status')
plt.ylabel('Count')
plt.show()

# %%
# Define features (df_train_x) and target (df_train_y)
df_train_x = df_train.drop('Loan_Status', axis=1)
df_train_y = df_train['Loan_Status']

# Split into 80% Training and 20% Validation
X_train, X_val, y_train, y_val = train_test_split(df_train_x, df_train_y, test_size=0.2, random_state=42)

print("Training Data shape:", X_train.shape)
print("Validation Data shape:", X_val.shape)
# Out:
# Training Data shape: (491, 11)
# Validation Data shape: (123, 11)

# %%
# Initialize and train the model
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Make predictions
y_pred = rf_model.predict(X_val)

# Calculate Accuracy
accuracy = accuracy_score(y_val, y_pred)
print(f"Model Accuracy: {accuracy * 100:.2f}%")

# Detailed Report
print("\nClassification Report:\n")
print(classification_report(y_val, y_pred))
# Out:
# Model Accuracy: 75.61%
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.42      0.55        43
#            1       0.75      0.94      0.83        80
#
#     accuracy                           0.76       123
#    macro avg       0.77      0.68      0.69       123
# weighted avg       0.76      0.76      0.73       123

# %%
# 1. Calculate the Confusion Matrix
# y_val = actual answers, y_pred = model's predictions
cm = confusion_matrix(y_val, y_pred)

# 2. Visualize it using a Heatmap
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Rejected (0)', 'Approved (1)'],
            yticklabels=['Rejected (0)', 'Approved (1)'])

plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix')
plt.show()

# %%
joblib.dump(rf_model, 'loan_model.joblib')
print("Model saved as 'loan_model.joblib'")
# Out:
# Model saved as 'loan_model.joblib'

# %%
# 1. Prepare Training Data
# X is the data, y is the answer
df_train_x = df_train.drop('Loan_Status', axis=1)
df_train_y = df_train['Loan_Status']

# 2. Split TRAIN data into "Teaching" (Train) and "Quizing" (Validation) sets
# We do this so we can calculate an accuracy score (metrics)
X_train, X_val, y_train, y_val = train_test_split(df_train_x, df_train_y, test_size=0.2, random_state=42)

# 3. Train the model
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

# 4. Check Accuracy (on the Validation set)
val_predictions = rf_model.predict(X_val)
print(f"Validation Accuracy: {accuracy_score(y_val, val_predictions) * 100:.2f}%")
# Out:
# Validation Accuracy: 75.61%

# %%
# --- PREDICTING ON THE REAL TEST DATA ---

# 1. We need to apply the SAME preprocessing to loan_test.csv
# (Handle missing values, encode text, etc. exactly like we did for train)
# For simplicity in this specific project, let's just do a quick clean matching previous steps:

# Fill missing values
df_test['LoanAmount'] = df_test['LoanAmount'].fillna(df_test['LoanAmount'].median())
df_test['Loan_Amount_Term'] = df_test['Loan_Amount_Term'].fillna(df_test['Loan_Amount_Term'].median())
df_test['Credit_History'] = df_test['Credit_History'].fillna(df_test['Credit_History'].mode()[0])
for col in ['Gender', 'Married', 'Dependents', 'Self_Employed']:
    df_test[col] = df_test[col].fillna(df_test[col].mode()[0])

# Encode text to numbers (using the same logic)
# Note: In a real strict pipeline, we would reuse the exact 'le' object, 
# but here we apply the same transformation logic.
le_test = LabelEncoder()
cols_to_encode_test = ['Gender', 'Married', 'Dependents', 'Education', 
                       'Self_Employed', 'Property_Area']

for col in cols_to_encode_test:
    df_test[col] = le_test.fit_transform(df_test[col])

# Drop Loan_ID if it exists
if 'Loan_ID' in df_test.columns:
    df_test_clean = df_test.drop('Loan_ID', axis=1)
else:
    df_test_clean = df_test

# 2. Make Final Predictions
final_predictions = rf_model.predict(df_test_clean)

# 3. Save Results
output = pd.DataFrame({'Loan_ID': pd.read_csv('loan_test.csv')['Loan_ID'], 
                       'Predicted_Status': final_predictions})

# Convert 1/0 back to Y/N for readability
output['Predicted_Status'] = output['Predicted_Status'].map({1: 'Y', 0: 'N'})

print("First 5 Predictions for Test File:")
print(output.head())

# Save to CSV if you want to submit or view it
output.to_csv('final_submission.csv', index=False)
# Out:
# First 5 Predictions for Test File:
#     Loan_ID Predicted_Status
# 0  LP001015                Y
# 1  LP001022                Y
# 2  LP001031                Y
# 3  LP001035                Y
# 4  LP001051                N
